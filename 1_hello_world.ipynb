# %%
"""
print() function
CTRL+enter을 누르면 실행
"""

print("Hello World!")
print(100)
pi=3.14
print(pi)

intro="My name is "
name="Chanoo Byun"
print(intro+name+"!")
"""
SHIFT+enter 새로운 실행창(?)만듬
"""
# Out:
# Hello World!
# 100
# 3.14
# My name is Chanoo Byun!

# %%
"""
Variables
"""

#나를 표현할수있는 정보 세 가지이상을 변수로 선언하시오

user_name="Chanoo Byun"
user_id=201855078
user_Phonenum="01088395508"
user_Age=23
user_Bloodtype="O"

#정수형 변수는 0부터쓰면안된다

# %%
"""
Data Types: Integer
"""
#집에 있는 사물중에서 세가지 이상을 정수 변수로 표현하시오

bed=3
computer=1
clock=2

# %%
"""
Data Types:Real Numbers
"""
#본인이 알고있는 세 개의 실수를 변수로 정의하시오

PI=3.14
Height=187.3
weight=78.6

# %%
"""
Data Types:Strings
"""
#본인이 좋아하는 문자열 3개를 만드시오
favorite_motto="Change favors the prepared mind."
favorite_game="League of legends"
favorite_athlete='Sonny'
print(favorite_motto)
print(favorite_game)
print(favorite_athlete)

favorites=favorite_motto+favorite_game+favorite_athlete

print(favorites)
# Out:
# Change favors the prepared mind.
# League of legends
# Sonny
# Change favors the prepared mind.League of legendsSonny

# %%
"""
x-Equals Operations
"""

a=2
a+=2
print(a)
# Out:
# 4

# %%
"""
Errors
"""

#Name Error
print (name1)
name1="Chanoo Byun"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-77351250422c> in <module>
#       4
#       5 #Name Error
# ----> 6 print (name1)
#       7 name1="Chanoo Byun"
#
# NameError: name 'name1' is not defined

# %%
#커서가 깜빡이는걸 프롬프트라고한다
